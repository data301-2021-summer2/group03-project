# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/5h/vl7fwhys13b4123xyqq__7mm0000gn/T/ipykernel_9427/3802347170.py in <module>
# ----> 1 from scripts import project_functions
#
# ImportError: cannot import name 'project_functions' from 'scripts' (/Users/weejiaquan/opt/anaconda3/lib/python3.8/site-packages/scripts/__init__.py)

# %%
# Method Chaining

df = pd.read_csv('../../data/raw/anime.csv')
df.head()


def load_and_process(result):
    # Method Chain 1 (Load data and deal with missing data)
    df1 = (
        result
    )
    df1 = df1[df1!= 'Unknown']

    # df1['Anime_ID'] = df1.index
    # Method Chain 2 (Create new columns, drop others, and do processing)
    df2 = (
        df1.drop(['MAL_ID','Producers', 'Licensors', 'English name', 'Japanese name'], axis=1)
        .dropna(axis='rows')
            # .rename(columns={"Weather_Conditions": "Weather_Type", "Did_Police_Officer_Attend_Scene_of_Accident": "Police_Presense"})
            # .replace({'Police_Presense': {'Yes': True, 'No': False}})
            # .replace({'Day_of_Week': {1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday', 7: 'Sunday'}})
            # .convert_dtypes()
            # .sort_values("Year", ascending=True)
    )
    #   df2['Date'] = pd.to_datetime(df2['Date'], format='%d/%m/%Y')

    # 

    return df2

load_and_process(df)
# Out:
# /var/folders/5h/vl7fwhys13b4123xyqq__7mm0000gn/T/ipykernel_9427/3947372129.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Duration (Minutes)'][ind] = convert(df2['Duration (Minutes)'][ind])
#                                                  Name Score  \
# 0                                        Cowboy Bebop  8.78
# 2                                              Trigun  8.24
# 3                                  Witch Hunter Robin  7.27
# 4                                      Bouken Ou Beet  6.98
# 5                                        Eyeshield 21  7.95
# ...                                               ...   ...
# 17178          Uma Musume: Pretty Derby (TV) Season 2  7.21
# 17224                             Wonder Egg Priority  8.32
# 17229                                   Gebäude Bäude  6.33
# 17328  Jimihen!!: Jimiko wo Kaechau Jun Isei Kouyuu!!  6.12
# 17469                    Wave!!: Surfing Yappe!! (TV)  6.05
#
#                                                   Genres Type Episodes  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space   TV       26
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen   TV       26
# 3      Action, Mystery, Police, Supernatural, Drama, ...   TV       26
# 4              Adventure, Fantasy, Shounen, Supernatural   TV       52
# 5                        Action, Sports, Comedy, Shounen   TV      145
# ...                                                  ...  ...      ...
# 17178                      Slice of Life, Comedy, Sports   TV       13
# 17224                      Psychological, Drama, Fantasy   TV       12
# 17229                                     Sci-Fi, Comedy   TV       10
# 17328                                     Romance, Ecchi   TV        8
# 17469                              Slice of Life, Sports   TV       12
#
#                               Aired    Premiered                   Studios  \
# 0       Apr 3, 1998 to Apr 24, 1999  Spring 1998                   Sunrise
# 2       Apr 1, 1998 to Sep 30, 1998  Spring 1998                  Madhouse
# 3       Jul 2, 2002 to Dec 24, 2002  Summer 2002                   Sunrise
# 4      Sep 30, 2004 to Sep 29, 2005    Fall 2004            Toei Animation
# 5       Apr 6, 2005 to Mar 19, 2008  Spring 2005                    Gallop
# ...                             ...          ...                       ...
# 17178              Jan 5, 2021 to ?  Winter 2021                Studio Kai
# 17224             Jan 13, 2021 to ?  Winter 2021               CloverWorks
# 17229   Nov 8, 2020 to Dec 10, 2020    Fall 2020  Jinnis Animation Studios
# 17328   Jan 4, 2021 to Feb 22, 2021  Winter 2021          Studio Hokiboshi
# 17469             Jan 12, 2021 to ?  Winter 2021          Asahi Production
#
#          Source Duration (Minutes)  ...  Score-10   Score-9   Score-8  \
# 0      Original                 24  ...  229170.0  182126.0  131625.0
# 2         Manga                 24  ...   50229.0   75651.0   86142.0
# 3      Original                 25  ...    2182.0    4806.0   10128.0
# 4         Manga                 23  ...     312.0     529.0    1242.0
# 5         Manga                 23  ...    9226.0   14904.0   22811.0
# ...         ...                ...  ...       ...       ...       ...
# 17178      Game                 23  ...     209.0     201.0     448.0
# 17224  Original                 23  ...    7564.0   12054.0   12657.0
# 17229  Original                  3  ...       6.0      11.0      19.0
# 17328     Manga                  3  ...     241.0     100.0     194.0
# 17469     Other                 23  ...     243.0     205.0     392.0
#
#        Score-7  Score-6  Score-5  Score-4  Score-3  Score-2  Score-1
# 0      62330.0  20688.0   8904.0   3184.0   1357.0    741.0   1580.0
# 2      49432.0  15376.0   5838.0   1965.0    664.0    316.0    533.0
# 3      11618.0   5709.0   2920.0   1083.0    353.0    164.0    131.0
# 4       1713.0   1068.0    634.0    265.0     83.0     50.0     27.0
# 5      16734.0   6206.0   2621.0    795.0    336.0    140.0    151.0
# ...        ...      ...      ...      ...      ...      ...      ...
# 17178    621.0    297.0    112.0     50.0     16.0     16.0     18.0
# 17224   5626.0   1516.0    682.0    258.0    113.0     77.0    144.0
# 17229     35.0     39.0     20.0      6.0      5.0      1.0      4.0
# 17328    343.0    426.0    282.0    143.0     91.0     70.0     80.0
# 17469    723.0    782.0    570.0    335.0    172.0     77.0     49.0
#
# [3306 rows x 30 columns]
